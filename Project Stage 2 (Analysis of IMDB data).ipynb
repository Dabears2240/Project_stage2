# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib as plt

# %%
plt = plt
df = pd.read_csv("/Users/drewkyser/Downloads/imdb_table.csv")
df.describe
# Out:
# <bound method NDFrame.describe of         ID rating                             movie_name   duration  year  \
# 0        1      8                             Death Note    126 min  2006
# 1        2    8.1                   Lage Raho Munna Bhai    144 min  2006
# 2        3      6                         The Thief Lord     98 min  2006
# 3        4    6.5                          Hollywoodland    126 min  2006
# 4        5    7.5                        Freedom Writers    123 min  2007
# 5        6    6.4                          Lies & Alibis     90 min  2006
# 6        7      8                     The Man from Earth     87 min  2007
# 7        8    4.9                Loveless in Los Angeles     95 min  2007
# 8        9    7.7                         Tekkonkinkreet    111 min  2006
# 9       10    6.3                        Blades of Glory  undefined  2007
# 10      11    7.1                            Quinceañera     90 min  2006
# ...

# %%
s = df['duration']
s.value_counts()
# Out:
# undefined    528
# 90 min       194
# 93 min       152
# 100 min      139
# 97 min       137
# 92 min       134
# 95 min       130
# 96 min       128
# 98 min       128
# 94 min       120
# 91 min       116
# 101 min      113
# 99 min       112
# 105 min      107
# 88 min       106
# 110 min       99
# 104 min       99
# 85 min        97
# 102 min       94
# 86 min        93
# 106 min       93
# 108 min       89
# 87 min        85
# 107 min       84
# 89 min        83
# 103 min       83
# 109 min       71
# 112 min       70
# 84 min        64
# 118 min       63
#             ...
# 154 min        2
# 172 min        2
# 55 min         2
# 63 min         2
# 70 min         2
# 72 min         2
# 170 min        2
# 183 min        1
# 213 min        1
# 198 min        1
# 171 min        1
# 320 min        1
# 193 min        1
# 56 min         1
# 181 min        1
# 166 min        1
# 46 min         1
# 164 min        1
# 62 min         1
# 237 min        1
# 196 min        1
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
s.value_counts().plot(kind='bar', use_index=False, fontsize = 5)

# %%
r = s.str.len()
r.describe()
# Out:
# count    4950.000000
# mean        6.786263
# std         0.899009
# min         6.000000
# 25%         6.000000
# 50%         7.000000
# 75%         7.000000
# max         9.000000
# Name: duration, dtype: float64

# %%
df['movie_name'].str.len().hist(bins=50)

# %%
y = df['content_rating'].value_counts()

# %%
y.get_value('undefined')
# Out:
# 796
